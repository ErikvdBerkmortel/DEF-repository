# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 54     |  |
# | :-------------|:-------------|
# | Erik van den Berkmortel | 6565182 |
# | Casper Aaldering | 6243193 |
# | Luc van der Wilt | 6430589 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 54     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 12:00 | Luc |
# | ontwerp-eis berekenen| 12:00 | Casper en Erik |
# | Eerste synthese van massa-veersysteem | 13:45-14:45 | hele groep |
# | Meten en itereren  | 15:00-16:45 | hele groep |
# | Vastgesteld welke metingen gedaan worden | 12:45 | hele groep|
# | ontwerp goedgekeurt | 15:00 | hele groep |
# | Ontwerp werkend| 16:45 | hele groep |
# | Pauze 1| 12:45 - 13:45 | hele groep |
# | Pauze 2| 15.30 - 15.45 | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 4 |
# | hoe lang voor één meting | 10s |
# | verwacht nauwkeurigheid meting | 8 procent |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %% [markdown]
# <img src="uitwerking eigenfrequentie.jpeg" width="400">
# Dit is de berekening die is uitgevoerd om de $f_0$ te berekenen van ons eigen dempingsysteem

# %%
def amplitudeoverdracht(f, f_0):
    return abs(1/ ((1-((2*np.pi*f)/(2*np.pi*f_0))**2)))

f = np.linspace(0,25,1000)
f0 = 5/2

plt.figure()
plt.plot(f, amplitudeoverdracht(f, f0))
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitudeoverdracht')
plt.loglog()
plt.show()

# %%
omega_0 = 2*np.pi*f0
g=9.81
delta_x = g/omega_0**2
print("delta x =", delta_x, "m")
# Out:
# delta x = 0.039758432461253344 m

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
def C(deltax,m):
    return (m*g)/deltax

Mtest = np.linspace(0.1,10,1000)
ctest_normaledelta = C(delta_x,Mtest)
ctest_2keerdelta = C(2*delta_x,Mtest)
ctest_5keerdelta = C(5*delta_x,Mtest)

plt.figure()
plt.plot(Mtest, ctest_normaledelta, label="met minimale delta_x")
plt.plot(Mtest, ctest_2keerdelta, label="met een twee keer zo grote delta_x")
plt.plot(Mtest, ctest_5keerdelta, label="met een vijf keer zo grote delta_x")
plt.legend()
plt.xlabel('Massa (kg)')
plt.ylabel('Veerconstante (N/m)')
plt.show()

# %% [markdown]
# Voor de schatting van de Youngs-modulus hebben we de veerconstante nodig deze berekenen we met $C = (m*g)/\Delta x$ Uit deze metingen hebben we gevonden dat met een massa aan de het elastiek van 417 gram, en een uitrekking van 7 cm. Dan is de veerconstante van 58.4 N/m. Met een schatting die is gedaan door de wortel te nemen van 0.001*0.01 (dit zijn de oppervlaktes waarvan we zeggen dat we het echt niet meer realistich vinden kunnen bij het oppervlakte van ), hieruit komt een schatting van het oppervlakte van 3.16 $mm^2$. De rustlengte hebben we gemeten, deze kwam uit op 3.7 cm. De Youngs-modulus komt dan met de formule $E=(CL)/A$ een uitkomst van E = 584

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - De massa in het massa-veersysteem verhogen
# - De veerconstante kunnen we verlagen om de $\Delta x$ te verhogen
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: we mikken op een $\Delta x$ van 6 cm, Dit willen we graag omdat we dan zekerheid hebben dat we ver genoeg weg zitten van de minimale $\Delta x$, maar dat het wel haalbaar lijkt te zijn voor wat we kunnen berijken met de beschikbare tijd en materialen

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="tekening_van_ontwerp.jpeg" width="400">
# Dit is de schets die we hebben gemaakt die de trilling onderaan bij het gewicht te dempen

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# **Voeg hier je antwoord in**
# de behaalde $\Delta x$ van het ontwerp is 5,86
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
# ja, hiermee wordt de minimale $\Delta x$ behaald, Het is net iets kleiner dan de gemikte $\Delta x$, maar prima voor de metingen.
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
# Het limiet van het massa veersysteem is bij een uitrekking van 30 centimeter niet meer lineair.
#
# **Voeg hier je antwoord in**
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# Dit is genoeg om zometeen de metingen te doen, want de uitrekking zal niet de maximale uitrekking bereiken, dus kunnen we hier de metingen mee doen
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# Het ontwerp zou moeten voldoen aan de eis, met de berekende veerconstante hebben we het theoretische gewicht berekend waarmee de $\Delta x$ van 6 centimeter, Met de gemeten waarde voor de meting, zou het volgens de theorie een goed resultaat moeten geven.
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
def amplitudeoverdracht(f, f_0):
    return abs(1/ ((1-((2*np.pi*f)/(2*np.pi*f_0))**2)))

f = np.linspace(0,25,1000)
f0_theorie = 5/2
f0_experiment = 2.03

plt.figure()
plt.plot(f, amplitudeoverdracht(f, f0_theorie), label="theorie")
plt.plot(f, amplitudeoverdracht(f, f0_experiment), label="experiment")
plt.legend()
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitudeoverdracht')
plt.loglog()
plt.show()

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
def amplitudeoverdracht(f, f_0):
    return abs(1/ ((1-((2*np.pi*f)/(2*np.pi*f_0))**2)))

f = np.linspace(0,25,1000)
f0_theorie = 5/2
f0_experiment = 2.26
data_overdracht = np.array([0.88/1.02, 5.23/7.32 , 1.37/5.88])
frequentie_gemeten = np.array([1, 3, 5])
plt.figure()
plt.plot(f, amplitudeoverdracht(f, f0_theorie), label="theorie")
plt.plot(f, amplitudeoverdracht(f, f0_experiment), label="experiment")
plt.errorbar(frequentie_gemeten, data_overdracht, yerr=0.3,xerr=0.1, fmt="k.", label="gemeten data")
plt.legend()
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitudeoverdracht')
plt.loglog()
plt.show()

# %% [markdown]
# Iteratie:
# Voor de iteratie hebben we voor deze uiteindelijke meting gaandeweg geittereerd. Het eerste idee was om het gewicht aan enkel 1 elastiek te hebben hangen, Echter werd het limiet van de elastiek toen wel bereikt tijdens de metingen, Hierna hebben we het gewicht wat verhoogd en nieuwe elastieken gebruikt. We hadden ook een probleem met de stabilitiet, dit hebben we opgelost door de beide elastieken niet op hetzelfde punt vast te zetten, maar verspreid over het bakje, hierdoor zwaaide het gewicht minder heen en weer en werden de metingen iets beter stabiel bleven.

# %% [markdown]
# Conclusie:
# Concluderend is de opstelling goed genoeg om in de gegeven eisen een goede meting te hebben, echter is de meting niet ideaal in de wiebeling, hij ging nog best veel van lings naar rechts, dit zou in volgende opdrachten verbeterd kunnen worden door aan meerdere kanten het gewicht te ondersteunen en de elastieken langer te maken.

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# hier de cellen voor leerdoel 1:

# %%
def C(deltax,m):
    return (m*g)/deltax

Mtest = np.linspace(0.1,10,1000)
ctest_normaledelta = C(delta_x,Mtest)
ctest_2keerdelta = C(2*delta_x,Mtest)
ctest_5keerdelta = C(5*delta_x,Mtest)

plt.figure()
plt.plot(Mtest, ctest_normaledelta, label="met minimale delta_x")
plt.plot(Mtest, ctest_2keerdelta, label="met een twee keer zo grote delta_x")
plt.plot(Mtest, ctest_5keerdelta, label="met een vijf keer zo grote delta_x")
plt.legend()
plt.xlabel('Massa (kg)')
plt.ylabel('Veerconstante (N/m)')
plt.show()

def amplitudeoverdracht(f, f_0):
    return abs(1/ ((1-((2*np.pi*f)/(2*np.pi*f_0))**2)))

f = np.linspace(0,25,1000)
f0_theorie = 5/2
f0_experiment = 2.26

plt.figure()
plt.plot(f, amplitudeoverdracht(f, f0_theorie), label="theorie")
plt.plot(f, amplitudeoverdracht(f, f0_experiment), label="experiment")
plt.legend()
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitudeoverdracht')
plt.loglog()
plt.show()

# %% [markdown]
# hier de cellen voor leerdoel 2:

# %% [markdown]
# <img src="tekening_van_ontwerp.jpeg" width="400">

# %%
def amplitudeoverdracht(f, f_0):
    return abs(1/ ((1-((2*np.pi*f)/(2*np.pi*f_0))**2)))

f = np.linspace(0,25,1000)
f0_theorie = 5/2
f0_experiment = 2.26
data_overdracht = np.array([0.88/1.02, 5.23/7.32 , 1.37/5.88])
frequentie_gemeten = np.array([1, 3, 5])
plt.figure()
plt.plot(f, amplitudeoverdracht(f, f0_theorie), label="theorie")
plt.plot(f, amplitudeoverdracht(f, f0_experiment), label="experiment")
plt.errorbar(frequentie_gemeten, data_overdracht, yerr=0.3,xerr=0.1, fmt="k.", label="gemeten data")
plt.legend()
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitudeoverdracht')
plt.loglog()
plt.show()

# %% [markdown]
# #### Als je je figuren onderweg opgeslagen hebt, kan je ze hier invoegen:
# <img src="opstelling.jpeg" width="400">
# <img src="tekening_van_ontwerp.jpeg" width="400">
